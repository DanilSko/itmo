# %% [markdown]
# ## Как использовать этот код
# ### (можно пропустить эту часть, если вы знаете, что такой Jupyter и ipynb-тетрадки -- в таком случае переходите сразу к "Начало работы")
# Перед вами тетрадка Jupyter Notebook. Это одна из популярных сред для написания и __демонстрации__ кода на Python (и не только). Jupyter запускает питоновский код прямо в браузере (но локально, т.е. код исполняет ваш компьютер, в отличие от, например Google Colab). В Jupyter код можно запускать не целиком, а по ячейкам. Пример:

# %%
# ячейка с кодом
text = 'Мы с Даней сегодня позапускаем морфоанализаторы'
print (text)
# Out:
# Мы с Даней сегодня позапускаем морфоанализаторы

# %%
# еще одна ячейка с кодом. 
# Пространство имен общее — переменная text была заполнена в предыдущей ячейке
print (text.upper())
# Out:
# МЫ С ДАНЕЙ СЕГОДНЯ ПОЗАПУСКАЕМ МОРФОАНАЛИЗАТОРЫ

# %% [markdown]
# Кроме того, ячейки бывают текстовыми — их можно форматировать с помощью формата разметки markdown (.md). Текст, который вы сейчас читаете, написан как раз в таком формате. Файлы Jupyter Notebook имеют расширение .ipynb и автоматически рендерятся гитхабом. Например, эта же __[тетрадка](https://github.com/DanilSko/itmo/blob/master/ITMO_practice/BasicProcessing/Basic%20text%20processing%20Danya%20ITMO.ipynb)__  у меня на гитхабе.

# %% [markdown]
# ## Окей, а как я могу запустить код в таком .ipynb?
#
# Есть разные варианты:
#
# ### Через __[Google Colab](https://colab.research.google.com)__.
#
# Google Colab — это гугловский инструмент для написания кода в браузере и запуска прямо на серверах Google (с возможностью бесплатно использовать их вычислительные мощности, в т.ч. графические процессор  — GPU).  Google Colab — родственник Jupyter, они очень похожи. Разница в том, что Jupyter работает локально и использует ваш собственный питон, а Google Colab — это облачный сервис, похожий на Google Docs: вы можете делиться тетрадками и т.д. В Colab можно открыть эту тетрадку, указав ссылку на нее:
#
# ![Colab](pics/github2colab.png)
#
# Просто загрузить .ipynb-файл в Colab тоже можно.
#
# ### Скачать себе .ipynb и открыть в Jupyter
#
# Скачать .ipynb с гитхаба:
#
# ![Raw](pics/raw_download.png)
#
# Поставить Jupyter Notebook по инструкции __[отсюда](https://jupyter.readthedocs.io/en/latest/install.html)__. Открыть терминал (в Windows — командную строку).пойти в папку, внутри которой лежит скачанный .ipynb, написать там jupyter notebook. Должно появиться что-то такое:
#
# ![Colab](pics/github2colab.png)
#
# Из Jupyter можно выгрузить код в виде файла .py
#
# ### Скачать .ipynb и открыть в PyCharm
# Если вы любите популярную у питонистов IDE PyCharm  -- она умеет открывать ipynb. Но для этого все равно нужен установеленный Jupyter. Поэтому надо проделать все то же, что в предыд.пункте, а потом открыть файл в PyCharm.
#
# ### (хак) Скачать файл .py из Google Colab или Jupyter и открыть в PyCharm или любой IDE
# Из Colab после создания копии вы можете выгрузить не весь .ipynb, а только код в .py. Этот код уже можно запускать где угодно, хоть из командной строки (терминала) вашего компьютера.

# %% [markdown]
# # Начало работы

# %%
#import nltk
import re

# %%
# проверим, что рядом в папке лежит файл с Преступлением и наказанием.
# !ls
# Out:
# Basic text processing Danya ITMO.ipynb Dostoevsky_PrestuplenieINakazanie.txt

# %%
## У тех, кто смотрит в колабе, его, естественно, не будет. Поэтому вот стандартный код для загрузки в колаб
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-9-d493b6e62670> in <module>()
#       1 ## У тех, кто смотрит в колабе, его, естественно, не будет. Поэтому вот стандартный код для загрузки в колаб
# ----> 2 from google.colab import files
#       3
#       4 uploaded = files.upload()
#       5
#
# ModuleNotFoundError: No module named 'google'

# %% [markdown]
#  __[Ссылка на текстовый файл с Преступлением и наказанием](https://github.com/DanilSko/itmo/blob/master/ITMO_practice/BasicProcessing/Dostoevsky_PrestuplenieINakazanie.txt)__.

# %%
# откроем файл в питоне
path_to_file = 'Dostoevsky_PrestuplenieINakazanie.txt'
prest_i_nak = open (path_to_file, 'r')
prest_i_nak_kak_stroka = prest_i_nak.read()

# %%
## попробуйте вывести тут длину строки с помощью функции len
len (prest_i_nak_kak_stroka)
# Out:
# 1094386

# %%
## попробуйте получить срез из первых 100 символов вашей строки с помощью срезов списка [:]
prest_i_nak_kak_stroka [:100]
# Out:
# 'Преступление и наказание \n\nРоман в шести частях с эпилогом\n\n  \nЧасть первая\n\nI\n\n   В начале июля, в '

# %% [markdown]
# # Сегментация текста

# %% [markdown]
# ## 0. Простейший способ сегментации строки на токены (как бы на слова, но тупее грубее) — питоновский встроенный метод .split:

# %%
prest_i_nak_kak_spisok_slov = prest_i_nak_kak_stroka.split(' ') ## здесь в качестве аргумента можно воткнуть разделитель; по умолчанию это любое количество пробелов
print ('Примерное количество слов в "Преступлении и наказании":', len (prest_i_nak_kak_spisok_slov))
# Out:
# Примерное количество слов в "Преступлении и наказании": 184153

# %%
prest_i_nak_kak_spisok_slov[:100]
# Out:
# ['Преступление',
#  'и',
#  'наказание',
#  '\n\nРоман',
#  'в',
#  'шести',
#  'частях',
#  'с',
#  'эпилогом\n\n',
#  '',
#  '\nЧасть',
#  'первая\n\nI\n\n',
#  '',
#  '',
#  'В',
#  'начале',
#  'июля,',
#  'в',
#  'чрезвычайно',
#  'жаркое',
#  'время,',
#  'под',
#  'вечер,',
#  'один',
#  'молодой',
#  'человек',
#  'вышел',
#  'из',
#  'своей',
#  'каморки,',
#  'которую',
#  'нанимал',
#  'от',
#  'жильцов',
#  'в',
#  'С',
#  '--',
#  'м',
#  'переулке,',
#  'на',
#  'улицу',
#  'и',
#  'медленно,',
#  'как',
#  'бы',
#  'в',
#  'нерешимости,',
#  'отправился',
#  'к',
#  'К',
#  '--',
#  'ну',
#  'мосту.\n',
#  '',
#  '',
#  'Он',
#  'благополучно',
#  'избегнул',
#  'встречи',
#  'с',
#  'своею',
#  'хозяйкой',
#  'на',
#  'лестнице.',
#  'Каморка',
#  'его',
#  'приходилась',
#  'под',
#  'самою',
#  'кровлей',
#  'высокого',
#  'пятиэтажного',
#  'дома',
#  'и',
#  'походила',
#  'более',
#  'на',
#  'шкаф,',
#  'чем',
#  'на',
#  'квартиру.',
#  'Квартирная',
#  'же',
#  'хозяйка',
#  'его,',
#  'у',
#  'которой',
#  'он',
#  'нанимал',
#  'эту',
#  'каморку',
#  'с',
#  'обедом',
#  'и',
#  'прислугой,',
#  'помещалась',
#  'одною',
#  'лестницей',
#  'ниже,',
#  'в']

# %% [markdown]
# ### попробуем получить список уникальных слов:

# %%
prest_i_nak_kak_mnojestvo_slov = set (prest_i_nak_kak_spisok_slov)
len (prest_i_nak_kak_mnojestvo_slov)
prest_i_nak_kak_spisok_unikalnyh_slov = list (prest_i_nak_kak_mnojestvo_slov)
(prest_i_nak_kak_spisok_unikalnyh_slov).sort()
prest_i_nak_kak_spisok_unikalnyh_slov [:1000]
# Out:
# ['',
#  '\x07паче',
#  '\n',
#  '\n\nРоман',
#  '\nII\n\n',
#  '\nIII\n\n',
#  '\nIV\n\n',
#  '\nV\n\n',
#  '\nVI\n\n',
#  '\nVII\n\n',
#  '\nVIII\n\n',
#  '\nТы',
#  '\nЧАСТЬ',
#  '\nЧасть',
#  '\nЭПИЛОГ\n\nI\n\n',
#  '"',
#  '"Cinq',
#  '"Confessions"',
#  '"Crevez',
#  '"Malborough',
#  '"tout',
#  '"А',
#  '"А!',
#  '"А,',
#  '"Ах',
#  '"Ах,',
#  '"Ба!',
#  '"Ба!"',
#  '"Ба,',
#  '"Беда!',
#  '"Бедная',
#  '"Безобразный',
#  '"Береги',
#  '"Благороднее",',
#  '"Богородицу"',
#  '"Боже',
#  '"Боже!',
#  '"Боже,',
#  '"Болезнь,',
#  '"Бросить',
#  '"Был',
#  '"В',
#  '"Важнее',
#  '"Ваше',
#  '"Видел,',
#  '"Видели,',
#  '"Видите,',
#  '"Вижу,',
#  '"Во',
#  '"Войду,',
#  '"Вона!',
#  '"Вот',
#  '"Вот,',
#  '"Врешь,',
#  '"Все',
#  '"Всё',
#  '"Выходите,',
#  '"Гамбринусе",',
#  '"Где',
#  '"Главное,',
#  '"Глупо!',
#  '"Гм,',
#  '"Гм...',
#  '"Господи!',
#  '"Гусара',
#  '"Да',
#  '"Да,',
#  '"Да-а',
#  '"Двадцать',
#  '"Действительно,',
#  '"Денег?',
#  '"Дескать,',
#  '"Для',
#  '"Довольно!',
#  '"Долго',
#  '"Должно',
#  '"Дорого,',
#  '"Друг',
#  '"Дунечка',
#  '"Дурак!"',
#  '"Египетские-то',
#  '"Еженедельная',
#  '"Ей',
#  '"Если',
#  '"Еще',
#  '"Ждет',
#  '"Женихов',
#  '"Живешь,',
#  '"Забыл,',
#  '"Зальюсь',
#  '"Заочно,',
#  '"Заперта;',
#  '"Зачем',
#  '"Зачем,',
#  '"Защити,',
#  '"Здесь!"',
#  '"Здравствуйте,',
#  '"Знает',
#  '"Знает!"',
#  '"Знать',
#  '"Значит,',
#  '"И',
#  '"И...',
#  '"Идет!',
#  '"Известно,',
#  '"Излер',
#  '"Иисус',
#  '"Или',
#  '"Илья',
#  '"Ишь',
#  '"К',
#  '"Кажется,',
#  '"Как',
#  '"Как!',
#  '"Как,',
#  '"Какая-нибудь',
#  '"Каким',
#  '"Капернаумов',
#  '"Карль',
#  '"Конечно,',
#  '"Короче',
#  '"Кошемар',
#  '"Красное,',
#  '"Кто',
#  '"Куда',
#  '"Куски',
#  '"Лжет!',
#  '"Лизавета!',
#  '"Лизаветина',
#  '"Лужину',
#  '"Лучше',
#  '"Любви',
#  '"Люби',
#  '"Малявочка',
#  '"Малявочка,',
#  '"Мария',
#  '"Матушка,',
#  '"Мать,',
#  '"Мизинца,',
#  '"Милостивая',
#  '"Милый',
#  '"Может',
#  '"Может,',
#  '"Московских',
#  '"Мы',
#  '"На',
#  '"На,',
#  '"Наверно,',
#  '"Надо',
#  '"Наконец-то',
#  '"Наполеон,',
#  '"Не',
#  '"Недели',
#  '"Несу,',
#  '"Нет,',
#  '"Неужели',
#  '"Неужели,',
#  '"Никогда',
#  '"Ничего',
#  '"Но',
#  '"Но...',
#  '"Ну',
#  '"Ну,',
#  '"О',
#  '"О,',
#  '"Об',
#  '"Общий',
#  '"Обыск,',
#  '"Он,',
#  '"Они!"\n',
#  '"От',
#  '"Отчего',
#  '"Охота',
#  '"Ошибка',
#  '"Пале',
#  '"Периодической',
#  '"Периодическою',
#  '"Периодическую".\n',
#  '"Петрушку"',
#  '"Погоди,',
#  '"Поди',
#  '"Пойдешь',
#  '"Покамест',
#  '"Полечка,',
#  '"Понимаете',
#  '"Поскорей',
#  '"После',
#  '"Послушайте!',
#  '"Посмотрим,',
#  '"Потом',
#  '"Потому',
#  '"Почему',
#  '"Прибежал-де',
#  '"Привидения',
#  '"Прииди!',
#  '"Прими,',
#  '"Пропаду',
#  '"Пусть',
#  '"Пусть,',
#  '"Пятна',
#  '"Разве',
#  '"Садись,',
#  '"Сам,',
#  '"Сама,',
#  '"Самая',
#  '"Свиньи',
#  '"Сдесь',
#  '"Се',
#  '"Сегодня',
#  '"Семен',
#  '"Сих',
#  '"Слава',
#  '"Со',
#  '"Сон',
#  '"Соне',
#  '"Стало',
#  '"Старушонка',
#  '"Стоит',
#  '"Судя',
#  '"Схоронены',
#  '"Та',
#  '"Таварищество",',
#  '"Так',
#  '"Так,',
#  '"Теперь',
#  '"Тогда',
#  '"Толстый',
#  '"Только',
#  '"Тут',
#  '"Ты',
#  '"У',
#  '"Уж',
#  '"Упокой,',
#  '"Урок',
#  '"Физиологию"',
#  '"Филька,',
#  '"Фу,',
#  '"Хорошее,',
#  '"Хорошо',
#  '"Хрустальном',
#  '"Хрустальный',
#  '"Хуторок"',
#  '"Хуторок",',
#  '"Хуторок".',
#  '"Хуторок"...',
#  '"Чего',
#  '"Человек',
#  '"Чем,',
#  '"Черт',
#  '"Что',
#  '"Что,',
#  '"Э!',
#  '"Эге,',
#  '"Эй',
#  '"Экая',
#  '"Экой',
#  '"Эта-то,',
#  '"Это',
#  '"Это,',
#  '"Этого',
#  '"Этому',
#  '"Эх!',
#  '"Эх,',
#  '"Эх-ма!"',
#  '"Юродивая!',
#  '"Я',
#  '"Я,',
#  '"а',
#  '"аршине',
#  '"без',
#  '"безобразия',
#  '"безобразную"',
#  '"беря',
#  '"бессмыслицей"',
#  '"билетика"',
#  '"билетиками",',
#  '"благороднее',
#  '"благороднее"?',
#  '"благородном',
#  '"благородном"',
#  '"благородном,',
#  '"благородных',
#  '"боится!"',
#  '"больные"',
#  '"больше,',
#  '"большие".\n',
#  '"будет!",',
#  '"будто',
#  '"в',
#  '"вакзал",',
#  '"вашу',
#  '"великодушнее"',
#  '"весьма',
#  '"вещь"',
#  '"вновь',
#  '"возлюби",',
#  '"вопрос',
#  '"вопрос",',
#  '"вопросе"',
#  '"вороваль",',
#  '"вот',
#  '"вошло!',
#  '"вошь"',
#  '"вояж"-то',
#  '"всеобщего',
#  '"всё',
#  '"гуманный"',
#  '"дай-ка,',
#  '"двадцать',
#  '"дворник,',
#  '"действительно',
#  '"деловой',
#  '"дельце",',
#  '"добра',
#  '"долг,',
#  '"дрожащая"',
#  '"дядьшки".\n',
#  '"если',
#  '"есть,',
#  '"еще',
#  '"желал',
#  '"жениха",',
#  '"женщины"?"\n',
#  '"за',
#  '"забавника",',
#  '"задушевный"',
#  '"заела',
#  '"заклад".',
#  '"засудят".',
#  '"зачитался",',
#  '"зваль',
#  '"злодеяние"?',
#  '"знакомый"',
#  '"и',
#  '"из',
#  '"известие"',
#  '"извозчик',
#  '"или',
#  '"или"?',
#  '"истинные"',
#  '"кажется",',
#  '"кажется,',
#  '"как',
#  '"каким',
#  '"коли',
#  '"коммуны"',
#  '"коммуны".',
#  '"которая',
#  '"ласково',
#  '"лязбиля"',
#  '"малодушии".\n',
#  '"мамасю"',
#  '"мамася',
#  '"матушка',
#  '"мелет',
#  '"мне',
#  '"много',
#  '"может',
#  '"можно',
#  '"молодой',
#  '"молодым',
#  '"молодых',
#  '"морской',
#  '"морскую',
#  '"на',
#  '"насилие",',
#  '"не',
#  '"независимость"',
#  '"немки",',
#  '"необыкновенную',
#  '"необыкновенный"',
#  '"необыкновенным"',
#  '"необыкновенных".',
#  '"необыкновенных-то"',
#  '"непремен',
#  '"несомненно"',
#  '"несчастную',
#  '"неужели',
#  '"ни',
#  '"низок',
#  '"ничего,',
#  '"ничтожным',
#  '"но',
#  '"новейших-то',
#  '"новое',
#  '"ноги',
#  '"ну',
#  '"ну!",',
#  '"о',
#  '"об',
#  '"обеих',
#  '"ободрить"',
#  '"образованный',
#  '"общественное',
#  '"общим',
#  '"обыкновенных"',
#  '"ожидании-то',
#  '"она',
#  '"осадила"',
#  '"освежает";',
#  '"оскорблял',
#  '"отвечала',
#  '"отрезала"',
#  '"отрезанный',
#  '"отчеканила",',
#  '"отъявленного',
#  '"отъявленного"',
#  '"пане',
#  '"пани',
#  '"пеняйте',
#  '"перезрелою',
#  '"перемените,',
#  '"по',
#  '"под',
#  '"подари',
#  '"подлец',
#  '"подождите"',
#  '"подходить',
#  '"подчеркнула"',
#  '"пока',
#  '"показание',
#  '"помешанный",',
#  '"помнила',
#  '"понимаете"?',
#  '"поручик-порох"...\n',
#  '"поскорей,',
#  '"пострадать',
#  '"пострадать?"',
#  '"потому',
#  '"потребностях"!',
#  '"похвальный',
#  '"правды',
#  '"представьте',
#  '"преставить",',
#  '"преступление,',
#  '"при',
#  '"приласкаешь,',
#  '"принял,',
#  '"проговорился",',
#  '"пролез"',
#  '"пронесется",',
#  '"пророк",',
#  '"пророка",',
#  '"протесты",',
#  '"прочти',
#  '"прощай"',
#  '"прощай".',
#  '"пусти"?',
#  '"пышную',
#  '"пьяный',
#  '"разрушителями"',
#  '"расторопный',
#  '"растреклятого',
#  '"решаешься"?\n',
#  '"руки',
#  '"рутину',
#  '"свой',
#  '"сегодня',
#  '"скорей",',
#  '"слова',
#  '"словно',
#  '"совсем',
#  '"сознаюсь"...',
#  '"сопоставить',
#  '"спасала"?',
#  '"спасти",',
#  '"среда',
#  '"среда"',
#  '"средой"',
#  '"стало',
#  '"старушонке"!',
#  '"страдай',
#  '"страдание',
#  '"страданье',
#  '"сцепились!"),',
#  '"сюрприз"?',
#  '"так,',
#  '"там"',
#  '"тех',
#  '"то',
#  '"турецким"',
#  '"тут',
#  '"у',
#  '"убеждения',
#  '"убийцу"',
#  '"удрученный")',
#  '"уж',
#  '"умеет',
#  '"услужливого',
#  '"устранять',
#  '"фамильный".',
#  '"фатер',
#  '"ход"',
#  '"хоть',
#  '"чего',
#  '"человек',
#  '"через',
#  '"черная",',
#  '"черной',
#  '"чистоту',
#  '"что',
#  '"чтоб',
#  '"чтобы',
#  '"шагающая',
#  '"швах",',
#  '"этот',
#  '"я',
#  '"я,',
#  '"язык',
#  '("матерчатое")',
#  '(Аниська',
#  '(Всего-то',
#  '(Вы',
#  '(Гм,',
#  '(Дворников-то,',
#  '(Действительно,',
#  '(Дуня',
#  '(Ему',
#  '(Заметьте',
#  '(И',
#  '(Катерина',
#  '(Лужин',
#  '(Мармеладов',
#  '(Николая)',
#  '(О,',
#  '(Однако',
#  '(Он',
#  '(Она',
#  '(Порфирий',
#  '(Потом',
#  '(Потому',
#  '(При',
#  '(Прореху-то',
#  '(Раскольников',
#  '(Раскольникову',
#  '(Сам',
#  '(Свидригайлов',
#  '(Соня',
#  '(Уж',
#  '(Черт',
#  '(Эта',
#  '(а',
#  '(ах,',
#  '(безответная',
#  '(беспокою',
#  '(бешенство',
#  '(более',
#  '(буквальное',
#  '(в',
#  '(вдруг',
#  '(вместо',
#  '(вот',
#  '(впрочем,',
#  '(все',
#  '(всё',
#  '(вы,',
#  '(говоря',
#  '(громко',
#  '(да',
#  '(да!',
#  '(да,',
#  '(деревянной',
#  '(ди',
#  '(для',
#  '(довольно',
#  '(доктор-то!),',
#  '(его',
#  '(единственное',
#  '(если',
#  '(еще',
#  '(желтый)',
#  '(за',
#  '(заметь',
#  '(и',
#  '(и,',
#  '(ибо',
#  '(ибо,',
#  '(или,',
#  '(или...',
#  '(иногда',
#  '(к',
#  '(как',
#  '(как-то',
#  '(когда',
#  '(когда-нибудь),',
#  '(которого',
#  '(которой',
#  '(который',
#  '(кто-то',
#  '(лат.).\n',
#  '(между',
#  '(на',
#  '(насилу',
#  '(находившейся',
#  '(не',
#  '(неизвестно',
#  '(некоторые,',
#  '(нем).]',
#  '(нем.)\n',
#  '(нем.).\n',
#  '(непременно',
#  '(несмотря',
#  '(ничем',
#  '(ну,',
#  '(обратился',
#  '(общий',
#  '(обыкновенных),',
#  '(он',
#  '(она',
#  '(особенно',
#  '(от',
#  '(отчего',
#  '(очень',
#  '(по',
#  '(последнее',
#  '(потому',
#  '(предположение',
#  '(про',
#  '(разбила).',
#  '(решетчатые,',
#  '(с',
#  '(сама',
#  '(самое',
#  '(своих-то',
#  '(свою',
#  '(сказали',
#  '(слышите,',
#  '(смысла',
#  '(совсем',
#  '(сопляк!),',
#  '(так',
#  '(теперь',
#  '(то',
#  '(тоже',
#  '(только',
#  '(траурная',
#  '(тысяч',
#  '(у',
#  '(уже',
#  '(указала',
#  '(франц.)\n',
#  '(франц.).\n',
#  '(франц.).]',
#  '(франц.)]',
#  '(ха-ха-ха!',
#  '(хоть',
#  '(хотя',
#  '(хотя,',
#  '(целый',
#  '(чего',
#  '(чему',
#  '(четвертую',
#  '(что',
#  '(что,',
#  '(шутки)',
#  '(это',
#  '(я',
#  '(я,',
#  '(я-то,',
#  '*',
#  '-',
#  '--',
#  '--\n',
#  '--"А',
#  '--"И',
#  '--"Не',
#  '--"Нет,',
#  '--до',
#  '--заторопился',
#  '--ков',
#  '--ой',
#  '--ому',
#  '--ский',
#  '.',
#  '.\n',
#  '...А',
#  '...Ваша',
#  '...Не',
#  '...Ну',
#  '...Он',
#  '...С',
#  '...Слаб',
#  '...Так',
#  '...У',
#  '1',
#  '1\n',
#  '19-го',
#  '196\n',
#  '2',
#  '2\n',
#  '298\n',
#  '32-го',
#  'A',
#  'Assez',
#  'Augen,\n',
#  'Cinq',
#  'Diamanten',
#  'Du',
#  'Ich',
#  'La',
#  'Madame',
#  'Madchen,',
#  'Malborough',
#  'Ne',
#  'Ou',
#  'Perlen...',
#  'Pour',
#  '[Довольно',
#  '[довольно',
#  '[милый',
#  '[надгробного',
#  '[напрасно!',
#  '[природа',
#  '[черным',
#  'adieu,',
#  'ami.',
#  'assez',
#  'autre.',
#  'bonne',
#  "c'est",
#  'cause!',
#  'cher',
#  'chiens,',
#  'cinq',
#  'comme',
#  'contents!"',
#  'court"',
#  'court?',
#  'danke,',
#  'de',
#  'die',
#  'distinguons.',
#  'droite!',
#  'du',
#  'en',
#  'est,',
#  'et',
#  'eternelle,',
#  'franГais.',
#  'funebre',
#  'guerre',
#  'guerre",',
#  'guerre,',
#  'guerre,\n',
#  'hast',
#  'humanum...',
#  'incognito-то-с,',
#  "j'ai",
#  'la',
#  'le',
#  'lettres,',
#  'madame',
#  'mauvais,',
#  'mehr,',
#  'mehr?',
#  'menage...',
#  'minimum',
#  'mon',
#  'monter',
#  "n'etes",
#  'nature',
#  'nicher?',
#  'nihil',
#  'notre',
#  'oraison',
#  'parlez-moi',
#  'pas',
#  'plaire...',
#  'plaisir,',
#  'pour',
#  'quand',
#  'reviendra...',
#  'rigueur,',
#  "s'en",
#  'sait',
#  'schonsten',
#  'se',
#  'si',
#  'sous"!',
#  'sous,',
#  'sous,\n',
#  'sous...\n',
#  'tenez-vous',
#  'theorie',
#  'tout',
#  'toutes',
#  'umsonst!',
#  'und',
#  'une',
#  'va-t-elle',
#  'va-t-en',
#  'verite!',
#  'vertu',
#  'vin',
#  'vive',
#  'vous',
#  'was',
#  'willst',
#  'А',
#  'А!',
#  'А!..',
#  'А,',
#  'А-а-а!',
#  'А-а-а,',
#  'А-а-а...\n',
#  'А-а-а?',
#  'А-ах!',
#  'А-зе',
#  'А-зе,',
#  'А-таки',
#  'А...',
#  'А?',
#  'А?\n',
#  'Авдотье',
#  'Авдотьей',
#  'Авдотьи',
#  'Авдотью',
#  'Авдотья',
#  'Авдотья-то',
#  'Авраама',
#  'Ага!',
#  'Адрес',
#  'Адрианополя.',
#  'Азии',
#  'Азии.',
#  'Ай',
#  'Александр',
#  'Александра',
#  'Александровна',
#  'Александровна,',
#  'Александровна.',
#  'Александровна.\n',
#  'Александровна;',
#  'Александровне',
#  'Александровне,',
#  'Александровне.',
#  'Александровне.\n',
#  'Александровной,',
#  'Александровну',
#  'Александровну.',
#  'Александровну.\n',
#  'Александровны',
#  'Александровны,',
#  'Александровны.\n',
#  'Александром',
#  'Алексей',
#  'Алена',
#  'Алена-то',
#  'Алене',
#  'Алену',
#  'Алены',
#  'Алешка.',
#  'Али',
#  'Аллах,',
#  'Алые',
#  'Аль',
#  'Альмы,',
#  'Амалией',
#  'Амалии',
#  'Амалию',
#  'Амалия',
#  'Амаль',
#  'Амаль-Иван!\n',
#  'Амаль-Иван,',
#  'Американским',
#  'Америку',
#  'Америку!',
#  'Америку,',
#  'Америку.\n',
#  'Америку?\n',
#  'Ангел',
#  'Англии,',
#  'Андрее',
#  'Андреем',
#  'Андрей',
#  'Андрею',
#  'Андрея',
#  'Аниська',
#  'Анна',
#  'Арестанта',
#  'Аркадий',
#  'Аркадий,',
#  'Аркадию',
#  'Аркадия',
#  'Артельщик',
#  'Аршин',
#  'Афанасий',
#  'Афанасию',
#  'Афанасия',
#  'Афанасия-то',
#  'Афанасьевича',
#  'Афанасьевичу.',
#  'Африке,',
#  'Афросиньюшка!',
#  'Афросиньюшки,',
#  'Ах',
#  'Ах!',
#  'Ах,',
#  'Ах..',
#  'Ахиллес',
#  'Ахиллес,',
#  'Ахиллесу',
#  'Ацтеки',
#  'Б--ну,',
#  'Ба!',
#  'Ба!..',
#  'Ба,',
#  'Баба',
#  'Бабенка',
#  'Бабочка',
#  'Бабушкина,',
#  'Бабушкина...\n',
#  'Бакалеева',
#  'Бакалеева,',
#  'Бакалеева.',
#  'Бакалеева.\n',
#  'Бакалеева...\n',
#  'Бакалееву,',
#  'Бартола',
#  'Барышня,',
#  'Батюшка!',
#  'Батюшка,',
#  'Батюшки!',
#  'Батюшки,',
#  'Бахуса.',
#  'Бегите,',
#  'Беда!',
#  'Беда!..',
#  'Бедная',
#  'Бедность',
#  'Бедные,',
#  'Бежать!',
#  'Без',
#  'Безземельная,',
#  'Безобразная,',
#  'Безобразно',
#  'Белинского',
#  'Белобрысые,',
#  'Белокурая',
#  'Белье',
#  'Берг',
#  'Бергом,',
#  'Берегись!',
#  'Берешь',
#  'Берите;',
#  'Берлин',
#  'Берлин,',
#  'Беру',
#  'Берусь!',
#  'Берут',
#  'Бесконечное',
#  'Беспокоит',
#  'Беспокойный',
#  'Беспокойным',
#  'Беспокойство',
#  'Бессильно',
#  'Бесчувственный,',
#  'Бешенство',
#  'Библию',
#  'Библия',
#  'Бивал',
#  'Била!',
#  'Благодарю',
#  'Благодарю-с.',
#  'Благодарю-с..\n',
#  'Благословляя',
#  'Бланбеки!',
#  'Бледно-желтое,',
#  'Бледное',
#  'Бледные',
#  'Близко.\n',
#  'Близость',
#  'Бог',
#  'Бог,',
#  'Богата',
#  'Богатый,',
#  'Боже',
#  'Боже,',
#  'Бойкая',
#  'Более',
#  'Болезненное',
#  'Болезнию',
#  'Болезнь',
#  'Болезнь,',
#  'Болен',
#  'Болен,',
#  'Болтушка',
#  'Боль',
#  'Больной',
#  'Больной.\n',
#  'Больной?\n',
#  'Большая',
#  'Больше',
#  'Больше,',
#  'Большою',
#  'Босенькая!',
#  'Боюсь',
#  'Боязнь',
#  'Боялся',
#  'Браво!']

# %% [markdown]
# ## 1. Более умный способ: сегментируем текст регекспом

# %%
prest_i_nak_spisok_re =  re.split ('( +|[.,!? –]|\n)',prest_i_nak_kak_stroka)

# %%
prest_i_nak_spisok_re [:10]
# Out:
# ['Преступление', ' ', 'и', ' ', 'наказание', ' ', '', '\n', '', '\n']

# %% [markdown]
# ## 2. Еще более умный способ: сегментируем текст готовым токенизатором — возьмем его из прекрасной библиотеки для обработки языка NLTK

# %%
# если у вас еще нет nltk, установите его:
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in /Users/daniilskorinkin/anaconda3/lib/python3.7/site-packages (3.4.1)
# Requirement already satisfied: six in /Users/daniilskorinkin/anaconda3/lib/python3.7/site-packages (from nltk) (1.12.0)

# %%
from nltk.tokenize import word_tokenize
prest_i_nak_nltk_tokenized = word_tokenize (prest_i_nak_kak_stroka)
prest_i_nak_nltk_tokenized_sample = prest_i_nak_nltk_tokenized [:100]

# %%
prest_i_nak_nltk_tokenized_sample
# Out:
# ['Преступление',
#  'и',
#  'наказание',
#  'Роман',
#  'в',
#  'шести',
#  'частях',
#  'с',
#  'эпилогом',
#  'Часть',
#  'первая',
#  'I',
#  'В',
#  'начале',
#  'июля',
#  ',',
#  'в',
#  'чрезвычайно',
#  'жаркое',
#  'время',
#  ',',
#  'под',
#  'вечер',
#  ',',
#  'один',
#  'молодой',
#  'человек',
#  'вышел',
#  'из',
#  'своей',
#  'каморки',
#  ',',
#  'которую',
#  'нанимал',
#  'от',
#  'жильцов',
#  'в',
#  'С',
#  '--',
#  'м',
#  'переулке',
#  ',',
#  'на',
#  'улицу',
#  'и',
#  'медленно',
#  ',',
#  'как',
#  'бы',
#  'в',
#  'нерешимости',
#  ',',
#  'отправился',
#  'к',
#  'К',
#  '--',
#  'ну',
#  'мосту',
#  '.',
#  'Он',
#  'благополучно',
#  'избегнул',
#  'встречи',
#  'с',
#  'своею',
#  'хозяйкой',
#  'на',
#  'лестнице',
#  '.',
#  'Каморка',
#  'его',
#  'приходилась',
#  'под',
#  'самою',
#  'кровлей',
#  'высокого',
#  'пятиэтажного',
#  'дома',
#  'и',
#  'походила',
#  'более',
#  'на',
#  'шкаф',
#  ',',
#  'чем',
#  'на',
#  'квартиру',
#  '.',
#  'Квартирная',
#  'же',
#  'хозяйка',
#  'его',
#  ',',
#  'у',
#  'которой',
#  'он',
#  'нанимал',
#  'эту',
#  'каморку',
#  'с']

# %% [markdown]
# # Стемминг, лемматизация, морфологический анализ

# %% [markdown]
# ### В том же NLTK есть готовая реализация стеммера для русского языка. Давайте потестируем ее!

# %%
from nltk.stem.snowball import SnowballStemmer
stemmer = SnowballStemmer("russian")

# %%
## этот стеммер не умеет сам токенизировать -- он работает только с отдельными словами. 
## Поэтому придется скармливать ему наш список по одному: 
prest_i_nak_stemmed = []
for word in prest_i_nak_nltk_tokenized_sample:
    prest_i_nak_stemmed.append (stemmer.stem(word))

# %%
prest_i_nak_stemmed
# Out:
# ['преступлен',
#  'и',
#  'наказан',
#  'рома',
#  'в',
#  'шест',
#  'част',
#  'с',
#  'эпилог',
#  'част',
#  'перв',
#  'I',
#  'в',
#  'начал',
#  'июл',
#  ',',
#  'в',
#  'чрезвычайн',
#  'жарк',
#  'врем',
#  ',',
#  'под',
#  'вечер',
#  ',',
#  'один',
#  'молод',
#  'человек',
#  'вышел',
#  'из',
#  'сво',
#  'каморк',
#  ',',
#  'котор',
#  'нанима',
#  'от',
#  'жильц',
#  'в',
#  'с',
#  '--',
#  'м',
#  'переулк',
#  ',',
#  'на',
#  'улиц',
#  'и',
#  'медлен',
#  ',',
#  'как',
#  'бы',
#  'в',
#  'нерешим',
#  ',',
#  'отправ',
#  'к',
#  'к',
#  '--',
#  'ну',
#  'мост',
#  '.',
#  'он',
#  'благополучн',
#  'избегнул',
#  'встреч',
#  'с',
#  'сво',
#  'хозяйк',
#  'на',
#  'лестниц',
#  '.',
#  'каморк',
#  'ег',
#  'приход',
#  'под',
#  'сам',
#  'кровл',
#  'высок',
#  'пятиэтажн',
#  'дом',
#  'и',
#  'поход',
#  'бол',
#  'на',
#  'шкаф',
#  ',',
#  'чем',
#  'на',
#  'квартир',
#  '.',
#  'квартирн',
#  'же',
#  'хозяйк',
#  'ег',
#  ',',
#  'у',
#  'котор',
#  'он',
#  'нанима',
#  'эт',
#  'каморк',
#  'с']

# %% [markdown]
# ## pymorphy

# %% [markdown]
# ## mystem

# %% [markdown]
# ### MyStem
#
# __[Mystem](https://tech.yandex.ru/mystem/)__ - это свободно распространяемый морфологический анализатор для русского языка с закрытым исходным кодом. То есть мы можем его бесплатно скачать с сайта и пользоваться им, но не можем посмотреть, что у него внутри и как оно работает.
#
# Mystem был придуман одним из создателей Яндекса Ильёй Сегаловичем. Некоторый потомок Mystem'а до сих пор работает внутри большого поисковика Яндекса, анализируя слова при поиске.
#
# MyStem значит my stemmer. Стемминг -- это разбиение формы на основу и флексию. Программы-стеммеры умеют превращать фразу 'Маша поехала за грибами' в 'Маш поехал за гриб'.
#
# Но на самом деле MyStem не стеммер, а полноценный морфологический анализатор. Он может гораздо больше: устанавливать словарную форму слова, определять часть речи и грамматические характеристики (падеж, число, время, род...). В последних версиях Mystem умеет и выбирать из нескольких возможных грамматических разборов один, наиболее верный.
#
# У Mystem нет графического оконного интерфейса, запустить его можно только из командной строки. Зато есть обертка для Python — pymystem3.
#
# __[Документация к MyStem](https://tech.yandex.ru/mystem/doc/index-docpage/)__

# %%
# эта клетка нужна вам, если у вас не установлен модуль pymystem3. 
# !pip install pymystem3
# Out:
# Collecting pymystem3
#   Using cached https://files.pythonhosted.org/packages/00/8c/98b43c5822620458704e187a1666616c1e21a846ede8ffda493aabe11207/pymystem3-0.2.0-py3-none-any.whl
# Requirement already satisfied: requests in /Users/daniilskorinkin/anaconda3/lib/python3.7/site-packages (from pymystem3) (2.21.0)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /Users/daniilskorinkin/anaconda3/lib/python3.7/site-packages (from requests->pymystem3) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in /Users/daniilskorinkin/anaconda3/lib/python3.7/site-packages (from requests->pymystem3) (2.8)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /Users/daniilskorinkin/anaconda3/lib/python3.7/site-packages (from requests->pymystem3) (1.24.2)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/daniilskorinkin/anaconda3/lib/python3.7/site-packages (from requests->pymystem3) (2019.3.9)
# Installing collected packages: pymystem3
# Successfully installed pymystem3-0.2.0

# %%
## импортируем непосредственно класс "анализатор MyStem" из pymystem3
from pymystem3 import Mystem

help (Mystem()) ## всегда полезно почитать хелпы!
# Out:
# Help on Mystem in module pymystem3.mystem object:
#
# class Mystem(builtins.object)
#  |  Wrap mystem binary to be able it use from Python.
#  |
#  |  The two main methods you may use are the :py:meth:`__init__` initializer,
#  |  and the :py:meth:`analyze` method to process your data and get mystem
#  |  output results.
#  |
#  |  :param  mystem_bin: path to mystem binary
#  |  :type   mystem_bin: str
#  |  :param  grammar_info: glue grammatical information for same lemmas in output.
#  |  :type   grammar_info: bool
#  |  :param  disambiguation: apply disambiguation
#  |  :type   disambiguation: bool
#  |  :param  entire_input: copy entire input to output
#  |  :type   entire_input: bool
#  |  :param  weight: print context-independent lemma weight
#  |  :type   weight: bool
#  |
#  |  .. note:: Default value of :py:attr:`mystem_bin` can be overwritted by :envvar:`MYSTEM_BIN`.
#  |
#  |  Methods defined here:
#  |
#  |  __del__(self)
#  |
#  |  __enter__(self)
#  |
#  |  __exit__(self, exc_type, exc_val, exc_tb)
#  |
#  |  __init__(self, mystem_bin=None, grammar_info=True, disambiguation=True, entire_input=True, weight=True)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  analyze(self, text)
#  |      Make morphology analysis for a text.
#  |
#  |      :param  text:   text to analyze
#  |      :type   text:   str
#  |      :returns:       result of morphology analysis.
#  |      :rtype:         dict
#  |
#  |  close(self)
#  |
#  |  lemmatize(self, text)
#  |      Make morphology analysis for a text and return list of lemmas.
#  |
#  |      :param  text:   text to analyze
#  |      :type   text:   str
#  |      :returns:       list of lemmas
#  |      :rtype:         list
#  |
#  |  start(self)
#  |      Run mystem binary.
#  |
#  |      .. note:: It is not mandatory to call it. Use it if you want to avoid waiting for mystem loads.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)

# %%
moi_analizator = Mystem() ## создаем анализатор
test = 'Даня тестирует машинную морфологию' ## создаем тестовую строку
lemmatized = moi_analizator.lemmatize(test) ## лемматизируем строку с помощью mystem 
print (lemmatized) ## напечатаем лемматизированную строку
# Out:
# ['даня', ' ', 'тестировать', ' ', 'машинный', ' ', 'морфология', '\n']

# %%
prest_i_nak_by_mystem = moi_analizator.analyze(prest_i_nak_kak_stroka[:100]) # произведем морфологический анализ с помощью mystem 
print  (prest_i_nak_kak_by_mystem)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-1404a70e260a> in <module>()
# ----> 1 prest_i_nak_kak_by_mystem = moi_analizator.analyze(prest_i_nak_kak_stroka[:100]) # произведем морфологический анализ с помощью mystem
#       2 print  (prest_i_nak_kak_by_mystem)
#
# NameError: name 'prest_i_nak_kak_stroka' is not defined
